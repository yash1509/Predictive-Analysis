# %% [markdown]
# #### Matplotlib and numpy practice session :-

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[15,16,20,25],'ro')
plt.ylabel('show numbers')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t=np.arange(0,5,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %%
# %matplotlib inline
x=([1,2,3,4])
y=([10,20,30,40])
plt.plot(x, y, linewidth=2.0)

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False)

# %%
x1=([1,2,3,4])
x2=([5,10,13,23])
y1=([45,100,23,3])
y2=(1,6,7,10)
lines=plt.plot(x1,y1,x2,y2)

# %%
lines = plt.plot(x1, y1, x2, y2)
plt.setp(lines, color='r', linewidth=2.0)
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# Out:
# [None, None, None, None]

# %%
lines = plt.plot([1, 2, 3])
plt.setp(lines)
# Out:
#   agg_filter: unknown
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: [True | False]
#   antialiased or aa: [True | False]
#   axes: an :class:`~matplotlib.axes.Axes` instance
#   clip_box: a :class:`matplotlib.transforms.Bbox` instance
#   clip_on: [True | False]
#   clip_path: [ (:class:`~matplotlib.path.Path`, :class:`~matplotlib.transforms.Transform`) | :class:`~matplotlib.patches.Patch` | None ]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' | 'steps-post']
#   figure: a :class:`matplotlib.figure.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: string or anything printable with '%s' conversion.
# ...

# %% [markdown]
# #### Multiple Figure and axes

# %%
import numpy as np
import matplotlib.pyplot as plt

def func(t):
    return np.exp(-t)*np.cos(2*np.pi*t)

a1=np.arange(0,5,1.0)
a2=np.arange(0,5,0.2)

plt.figure(1)
plt.subplot(211)
plt.plot(a1,func(a1),'bo',a2,func(a2),'k')

plt.subplot(212)
plt.plot(a2,np.cos(2*np.pi*a2),'r--')

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.subplot(211)
plt.plot([1,2,3,4])
plt.subplot(211)
plt.plot([20,40,50,6])

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.subplot(211)
plt.plot([1,2,3,4])
plt.subplot(212)
plt.plot([20,40,50,6])

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.subplot(211)
plt.plot([1,2,3,4])
plt.subplot(211)
plt.plot([20,40,50,6])

plt.figure(2)
plt.subplot(212)
plt.plot([2,23,4,67])

plt.figure(1)
plt.subplot(211)
plt.title("Easy structuring")

plt.figure(2)
plt.subplot(212)
plt.title("Testing complete")

# %%
plt.close()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(17712771)
mu,sigma=15,32

x=mu*sigma*np.random.randn(8293)

plt.figure(1)
plt.subplot(211)
n,bin,patch=plt.hist(x,50,normed=1, facecolor='g', alpha=0.75)

plt.xlabel('x-axis',color='red')
plt.ylabel('y-label')
plt.title('Text practice on graph')

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(17712771)
mu,sigma=15,32

x=mu*sigma*np.random.randn(8293)

plt.figure(1)
plt.subplot(211)
n,bin,patch=plt.hist(x,50,normed=1, facecolor='g', alpha=0.75)

plt.xlabel('x-axis',color='red')
plt.ylabel('y-label')
plt.title('Text practice on graph')
plt.title(r'$\sigma_i=15$')

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(3, 1), xytext=(4, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1123123121)

y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

plt.figure(1)
plt.subplot(221)
plt.plot(x,y)
plt.title('linear')
plt.grid(True)

plt.subplot(222)
plt.plot(x,y)
plt.title('log')
plt.grid(True)

plt.subplot(223)
plt.plot(x, y - y.mean())
plt.title('symlog')
plt.grid(True)

plt.subplot(224)
plt.plot(x, y)
plt.title('logit')
plt.grid(True)

plt.subplots_adjust(top=1, bottom=0.10, left=0.05, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# #### Heatmap:

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.random.random((16, 16))
print(a)
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show()
# Out:
# [[ 0.458341    0.30202472  0.99253413  0.95641458  0.52986173  0.49832729
#    0.44274311  0.37208208  0.12488834  0.90958834  0.29523157  0.42274124
#    0.5475131   0.97827034  0.5239015   0.43590445]
#  [ 0.87702347  0.60827177  0.04517437  0.71187544  0.23858895  0.64471506
#    0.68042773  0.004481    0.00560161  0.58687979  0.54801701  0.64030799
#    0.66166487  0.91003667  0.95208229  0.45472515]
#  [ 0.86576591  0.03717894  0.91915118  0.59860669  0.51571964  0.25781916
#    0.75715016  0.84046556  0.00308689  0.86117878  0.9607552   0.27949885
#    0.79377635  0.93818394  0.36248155  0.12137095]
#  [ 0.89093057  0.69726098  0.04739442  0.3639557   0.86509642  0.40930128
#    0.3043383   0.98435184  0.28119813  0.24099697  0.27222278  0.98386924
#    0.34186643  0.39115766  0.07376269  0.22717604]
#  [ 0.25266245  0.71963314  0.95687039  0.4645531   0.24984587  0.22912982
#    0.55475912  0.72725446  0.15980514  0.1053229   0.49665658  0.43809729
# ...

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.plot(x,y,'g',label='line one', linewidth=5)
plt.plot(x2,y2,'c',label='line two',linewidth=5)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.legend()

plt.grid(True,color='k')

plt.show()
